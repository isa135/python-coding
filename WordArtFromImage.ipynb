# %% [markdown]
# <a href="https://colab.research.google.com/github/isa135/python-coding/blob/main/WordArtFromImage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
Image.open("dory.png")
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=480x480 at 0x7FBB96BF7690>
